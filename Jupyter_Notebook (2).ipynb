# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio<h1>

# %% [markdown]
# **Swathi Burgula**<br>
# Data Scientist

# %% [markdown]
# *I am interested in data science because because I like to analyse the data and I love to creating plots, graphs, etc. And nowadays Data Scientist is more popular technology.*

# %% [markdown]
# <h3>In the next cell my code gonna perform addition 3+4 and it'll give output as 7</h3>

# %%
print(3+4)
# Out:
# 7

# %% [markdown]
# <ol>
#     <li><a href=data:image/jpeg;base64,...><s>Apple</s></a></li>
#     <li><a href= https://upload.wikimedia.org/wikipedia/commons/thumb/8/8a/Banana-Single.jpg/2324px-Banana-Single.jpg><s>Banana</s></a></li>
#     <li><a href=data:image/jpeg;base64,...><s>Cherry</s></a></li>
#     <li><a href=data:image/jpeg;base64,...><s>Orange</s></a></li>
# </ol>
